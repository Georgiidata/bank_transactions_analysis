# %%
import pandas as pd

df = pd.read_csv("C:/Users/ghsh/bank_transactions_analysis/data/bank_transactions.csv")
print(df.head())
# Out:
#    transaction_id        date  amount       category  balance_after  \
# 0               1  2024-01-01 -118.04  Entertainment        1881.96
# 1               2  2024-01-02 -337.09  Entertainment        1544.87
# 2               3  2024-01-03 -265.16        Grocery        1279.71
# 3               4  2024-01-04  -28.60  Entertainment        1251.11
# 4               5  2024-01-05  -51.05          Bills        1200.06
#
#   transaction_type
# 0          Expense
# 1          Expense
# 2          Expense
# 3          Expense
# 4          Expense

# %%
# Загрузка данных
df = pd.read_csv("C:/Users/ghsh/bank_transactions_analysis/data/bank_transactions.csv")

# Основная статистика
print("Основная статистика:")
print(df.describe())

# Число транзакций по каждой категории
print("\nЧисло транзакций по категориям:")
print(df['category'].value_counts())

# Средняя сумма по типу транзакции (Expense vs Income)
print("\nСредняя сумма по типу транзакции:")
print(df.groupby('transaction_type')['amount'].mean())

# Распределение баланса после транзакций
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['balance_after'], bins=30, color='skyblue', edgecolor='black')
plt.title("Распределение баланса после транзакций")
plt.xlabel("Баланс после транзакции")
plt.ylabel("Частота")
plt.show()
# Out:
# Основная статистика:
#        transaction_id       amount  balance_after
# count      100.000000   100.000000     100.000000
# mean        50.500000   715.962500   35259.640000
# std         29.011492  1723.808194   20719.594523
# min          1.000000  -499.840000     355.640000
# 25%         25.750000  -321.095000   23075.867500
# 50%         50.500000  -154.695000   32455.225000
# 75%         75.250000  1688.305000   49226.675000
# max        100.000000  4847.680000   73990.960000
#
# Число транзакций по категориям:
# category
# Rent             16
# Entertainment    14
# Freelance        14
# Bills            14
# Salary           13
# Transport        13
# Grocery           9
# Shopping          7
# Name: count, dtype: int64
#
# Средняя сумма по типу транзакции:
# transaction_type
# Expense    -259.163014
# Income     3352.412963
# Name: amount, dtype: float64

# %%
large_transactions = df[df['amount'].abs() > 1000]

# 2. Частые транзакции: сортируем по дате и считаем количество транзакций за день
df['date'] = pd.to_datetime(df['date'])
df['transaction_count_per_day'] = df.groupby('date')['transaction_id'].transform('count')

# 3. Подозрительные категории: фильтруем на случайные категории, если такие будут
suspicious_categories = ["Freelance", "Loan", "Unusual Category"]
suspicious_transactions = df[df['category'].isin(suspicious_categories)]

# Выводим результаты
print("Подозрительные транзакции (сумма > 1000):")
print(large_transactions)

print("\nТранзакции с частотой больше 5 за день:")
print(df[df['transaction_count_per_day'] > 5])

print("\nПодозрительные категории транзакций:")
print(suspicious_transactions)
# Out:
# Подозрительные транзакции (сумма > 1000):
#     transaction_id        date   amount   category  balance_after  \
# 8                9  2024-01-09  2207.75     Salary        2563.39
# 9               10  2024-01-10  2295.39     Salary        4858.78
# 12              13  2024-01-13  4648.16  Freelance        9186.66
# 16              17  2024-01-17  4810.57     Salary       13426.20
# 19              20  2024-01-20  2970.23  Freelance       16168.51
# 22              23  2024-01-23  4564.11  Freelance       19862.38
# 24              25  2024-01-25  1907.34  Freelance       21577.63
# 25              26  2024-01-26  1997.65  Freelance       23575.28
# 26              27  2024-01-27  2532.95     Salary       26108.23
# 27              28  2024-01-28  2260.72     Salary       28368.95
# 35              36  2024-02-05  4427.10  Freelance       30763.88
# 44              45  2024-02-14  4202.52     Salary       33489.80
# 54              55  2024-02-24  4581.25     Salary       35468.71
# 59              60  2024-02-29  4218.44     Salary       38046.33
# 60              61  2024-03-01  4847.68     Salary       42894.01
# 68              69  2024-03-09  4723.47  Freelance       45262.71
# 70              71  2024-03-11  4381.29     Salary       49492.40
# 75              76  2024-03-16  1630.26  Freelance       49566.77
# 77              78  2024-03-18  4545.80  Freelance       53632.50
# 78              79  2024-03-19  2802.37     Salary       56434.87
# 81              82  2024-03-22  3763.98  Freelance       59579.24
# 87              88  2024-03-28  1862.44     Salary       59956.11
# 88              89  2024-03-29  1330.41  Freelance       61286.52
# 89              90  2024-03-30  3742.00     Salary       65028.52
# 91              92  2024-04-01  3669.74  Freelance       68565.03
# 92              93  2024-04-02  2244.79  Freelance       70809.82
# 95              96  2024-04-05  3346.74  Freelance       73990.96
#
#    transaction_type
# 8            Income
# 9            Income
# 12           Income
# 16           Income
# 19           Income
# 22           Income
# 24           Income
# 25           Income
# 26           Income
# 27           Income
# 35           Income
# 44           Income
# 54           Income
# 59           Income
# 60           Income
# 68           Income
# 70           Income
# 75           Income
# 77           Income
# 78           Income
# 81           Income
# 87           Income
# 88           Income
# 89           Income
# 91           Income
# 92           Income
# 95           Income
#
# Транзакции с частотой больше 5 за день:
# Empty DataFrame
# Columns: [transaction_id, date, amount, category, balance_after, transaction_type, transaction_count_per_day]
# Index: []
#
# Подозрительные категории транзакций:
#     transaction_id       date   amount   category  balance_after  \
# 12              13 2024-01-13  4648.16  Freelance        9186.66
# 19              20 2024-01-20  2970.23  Freelance       16168.51
# 22              23 2024-01-23  4564.11  Freelance       19862.38
# 24              25 2024-01-25  1907.34  Freelance       21577.63
# 25              26 2024-01-26  1997.65  Freelance       23575.28
# 35              36 2024-02-05  4427.10  Freelance       30763.88
# 68              69 2024-03-09  4723.47  Freelance       45262.71
# 75              76 2024-03-16  1630.26  Freelance       49566.77
# 77              78 2024-03-18  4545.80  Freelance       53632.50
# 81              82 2024-03-22  3763.98  Freelance       59579.24
# 88              89 2024-03-29  1330.41  Freelance       61286.52
# 91              92 2024-04-01  3669.74  Freelance       68565.03
# 92              93 2024-04-02  2244.79  Freelance       70809.82
# 95              96 2024-04-05  3346.74  Freelance       73990.96
#
#    transaction_type  transaction_count_per_day
# 12           Income                          1
# 19           Income                          1
# 22           Income                          1
# 24           Income                          1
# 25           Income                          1
# 35           Income                          1
# 68           Income                          1
# 75           Income                          1
# 77           Income                          1
# 81           Income                          1
# 88           Income                          1
# 91           Income                          1
# 92           Income                          1
# 95           Income                          1

# %%
import seaborn as sns
df = pd.read_csv("C:/Users/ghsh/bank_transactions_analysis/data/bank_transactions.csv")
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["amount"], color="red")
plt.title("🔎 Выявление аномальных транзакций (выбросы)")
plt.xlabel("Сумма транзакции")
plt.show()
# Out:
# C:\Users\ghsh\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128270 (\N{RIGHT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["date"], df["balance_after"], marker="o", linestyle="-", color="blue")
plt.title("📅 Динамика баланса со временем")
plt.xlabel("Дата")
plt.ylabel("Баланс")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# C:\Users\ghsh\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128197 (\N{CALENDAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv("C:/Users/ghsh/bank_transactions_analysis/data/bank_transactions.csv")
# Настройки графиков
plt.style.use("ggplot")

# Группируем суммы по категориям
category_totals = df.groupby("category")["amount"].sum().sort_values()

# Столбчатая диаграмма расходов по категориям
plt.figure(figsize=(12, 6))
category_totals.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("📊 Расходы и доходы по категориям")
plt.xlabel("Категория")
plt.ylabel("Сумма")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\ghsh\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
